# %%
import requests

url = "https://api-iot.digital-lab.mx/transportes/metrobus/locations"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)  # Datos de ubicación de unidades
else:
    print("Error al obtener datos")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# ...

# %%
import requests

url = "https://pokeapi.co/api/v2/pokemon/ditto"

try:
    response = requests.get(url)
    response.raise_for_status()  # Lanza una excepción para códigos de estado HTTP incorrectos
    data = response.json()
    print(data)
except requests.exceptions.RequestException as e:
    print(f"Error al obtener datos: {e}")
except ValueError:
    print("Error: Respuesta de la API no es un JSON válido")

# %%
pip install pandas requests geopandas sqlalchemy geopy

# %%
pip install protobuf

# %%
# Out:
#   Cell In[1], line 1
#     protoc --python_out=. gtfs-realtime.proto
#     ^
# SyntaxError: cannot assign to expression

# %%
# Out:
# Error: The content is not decodable as UTF-8. Saving as binary.
# File saved as gtfs-realtime.bin

# %%
import requests

url = "https://tw15nm0b.r.us-east-1.awstrack.me/L0/https:%2F%2Fsonda-gtfs-prd.s3.amazonaws.com%2F1339%2FMetrobus_GTFS_RT.proto%3FX-Amz-Security-Token=IQoJb3JpZ2luX2VjEDUaCXVzLWVhc3QtMSJIMEYCIQDT%252Bd%252B%252FUXxmn5Wlh0yK%252FL9sxY0jgzmCRXAxNADW55GYeQIhANR9CVWZ8RokwqUJ6A8whspqvLk4RnLHd3uMA0NfR6aPKroFCJ3%252F%252F%252F%252F%252F%252F%252F%252F%252F%252FwEQBBoMMjkwMzg5OTEzNTc2Igx45%252F1dkHj24qk9msEqjgUMv9RLaOk9ov2K7HnXzivb0Uch05dFVOu7I4b6h0lexGyma6Xfwt2B%252BD07HhKcEbtBuOLOWkxaLWmemgQTD9RVetRKjdmWTEU3w4glvayYT%252Bzge2UOIXS02VNGsPH27hVKhtIzFNxwJAF0DhPg6Jy2qcCnr2foZWiQ0NA%252FR3uWHIYyAzyxCYEafHT3GtWRB%252BZc01jIr2OicOY768foqMmArJ7e5l7SfHWVROswVLskeCpmFzvcdqhohXT2W%252FGScm8ft3RpwT4kBJdUXsAtMcmsM2MYkPJGra8oXu%252F9OvsxuWAG5mnrblVODXLloSgrzRSR1KLx5YJGhP3sd9XAAFM8xTBz5kY3Ti0lcX0LYOsBuZc1gdF5XK4CFTpxrdABjphMLn6muRrbGEd5J6Ua6dv9FuWVc0igIqxhyiTxNZYCQpNWZmXAEeBv7B15rjBxQluaFbN661V%252FJqv770DHGHFobMvbdCfeKcUtW7HNmyKwjbptszRX7hl%252FXoeImY06eMLWpbX3gCfcYTPEi79b0OfGfVrLaxEkjl0LvUyBf4pgdIYkeRomFaSHBC%252FdHwnb3KgNxwdHxej%252BEJx6oL16vcDLat68In3hzBqvIpvLECEj9LfZ6xviVbQ1tvX833lgbTaooFW98CZVkTs7DsGZV%252BGPRaDS5LMefBC3goCIajixgtgz0ALe6SohUYlrYdN2542R3FrJ%252FPY68kxPgAOrc0WvYwOJNUmNmIw4SdRFDnrRYkrmQ14MkX45UTiw83FAG0t8AGjcsIsf4sZjwE8VyTZuCKzg2nUy887bufnmNnwYkegbsRc36B63VCRnbYmxD9v73Y8HqJZKUgy9VXP35eGcUDV4neK%252FkNyE8G2nMNAwla%252BovwY6sAEmwc2fQyqYGFon57ToDvGsaBns0FsKgVusGt1poRnpnj7%252FOZl1M%252Bf8rh3Nmw6oEm%252BTUsSQErwneMGy5KuxYajdjN54rP6m%252FSACvRbAghhLYKej4uGB5TtuQKsZP3WZxL5kaavFogzH4a2uor9tFAEfPmCgzvEj3mHAr5pbdEvJuZ8tBeZBTD3%252BsPJ7mZKJXkfsSsoV13B%252BOME%252Bn%252Fea1y%252F3qhRgk5A2golNZei7eTBFoQ%253D%253D%26X-Amz-Algorithm=AWS4-HMAC-SHA256%26X-Amz-Date=20250331T050928Z%26X-Amz-SignedHeaders=host%26X-Amz-Expires=43199%26X-Amz-Credential=ASIAUHHEWN7UNKZ22F3S%252F20250331%252Fus-east-1%252Fs3%252Faws4_request%26X-Amz-Signature=420c5e908ad5bfb685dc3e66cd01110c2dd46105d96292efee630aa97b996bdb/1/01000195ea9aced0-cb503e8f-920a-4e4d-bf07-1e11f1a6f02b-000000/9e_ItO9u5wKghB7jL9EpqAMHVtc=419"  # Tu URL completa

response = requests.get(url)
with open("gtfs-realtime.proto", "wb") as f:
    f.write(response.content)

# %%
from google.transit import gtfs_realtime_pb2
import requests

# URL del feed GTFS Realtime (deberías tener una similar para los datos en tiempo real)
feed_url = "https://tw15nm0b.r.us-east-1.awstrack.me/L0/https:%2F%2Fsonda-gtfs-prd.s3.amazonaws.com%2F1339%2FMetrobus_GTFS_RT.proto%3FX-Amz-Security-Token=IQoJb3JpZ2luX2VjEEgaCXVzLWVhc3QtMSJIMEYCIQDlE2zGSzxlP88iaDSFBFrlDYxm6nxPrO%252BOvyNkgD0wWAIhAKK%252FGQK2ZpgoeQ8YF084BQezTG5v5XVWhhf4nMGql3dkKroFCLD%252F%252F%252F%252F%252F%252F%252F%252F%252F%252FwEQBBoMMjkwMzg5OTEzNTc2IgyovW5XKTFODjKdfLAqjgXiWeH3%252BwBMOydTf8vNujFyxXcM1iF47AgmfLt4lN3HPK79LPWYsBArHKsyeDsHxjAvRbUoMYS3jfyRn8HvoUEfqm5itxVtD2%252FUUvDv0Ey8UT1BWWhYJ3IgcIddMUZ2hHPAdnRA%252Fut%252BchLGsJ9rH3OjuaCY9fegv2n1OIVqCz909h2Eni5n6jMnbOYJKisUT%252FkV3itJajqLnVkm16JsFUfGh6cEz7usjth4f7LsnoxZJb%252FnaPZkb8Y4tGi3kIXfurpYRyRPYJOI6IP09g1NaXKpp30%252BGfUlpkoJ1cY103tE9iOSznjiYrR3%252Bk%252F2UgQHcebLG2PFVAgMZWwk7QD3cradMiCj2BQsoxg5LhaBmIr0CsChOcHfKn6DV4w7ca8cEYchk%252FkQXiT9yzETZNzTRhfjfDrcRVI6zQYXFR1XWbeAKb198ihP7iprRR1vDr%252FlwsrvlDe2%252FX%252BzcVFA1CLp19sSjBVotwxDtAKl0RtHO0UA00TIXunqZN8XMlv9aDn9B2ucdutY4TR%252FZerfn9y8%252BeqITQRjRjwXK6SnxKWvU1oUi0dZbgADW0xLnLFRJ1HfoFhIE8d7TpPgWbCseA0vMUnIz0vKZ95dNmn7gwRLAdk8IuoxnNjOZkqWU1HR69RHe9CpSgnPnOSSHjvyhKiSsM57ne92X9ChiLtwpLJxdHgJkEUZDso8P7ArXt%252FIJhYL9k2fQ2MJ0SR28VDtHbtbyVQG2U6yl%252Fsz3NIwFw9Cfg7PE%252BW6oipeqBo1IMcs42zJKlKI91b2QlXCj23hCRux6AMzOyWLyjZ%252FvmxCfAEWNgM%252FATAUkCCKD7VfIAHqFShNhA%252F1jPlGP2XrXFIEXkHh1UFS%252F4wHexqWrHs2Fz6J4zwwgMesvwY6sAGGwgQW85bHxBRoU7vX1hK0exVEowF5rcEieaKAWPmcAyBv%252BzeYf6rgm39N2FVbIw4SfTWoMkWgzwsLW84oXpcgDSTOHpdk3hPKW4y7iX379U%252FOLlBTgORNIr51ENoUBZw0tbff2lsKwuVS5HlgjCAQMVB1QYDDg%252B6UrHFKtcFfoHcqgy2%252BOmrNItakKVQdv2hHaIvLetDGhhvfy05O4vJ84lWKaHWRYxGYL6xkKD3WVw%253D%253D%26X-Amz-Algorithm=AWS4-HMAC-SHA256%26X-Amz-Date=20250401T002637Z%26X-Amz-SignedHeaders=host%26X-Amz-Expires=43199%26X-Amz-Credential=ASIAUHHEWN7UIBFCHMFY%252F20250401%252Fus-east-1%252Fs3%252Faws4_request%26X-Amz-Signature=b78b3cb3766ea9a3537f7d04bee17bc8d8a8e7c56dca216b8841f1e6ebdc473a/1/01000195eebe33b9-8b9fe86b-368c-4de7-bee2-04c66de51d20-000000/GDicBwXW8HQMaKnMqvinLBf7D3Q=419"
response = requests.get(feed_url)
feed = gtfs_realtime_pb2.FeedMessage()
feed.ParseFromString(response.content)
# Out:
# 100845

# %%
feed
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1743467368
# }
# entity {
#   id: "2b0af44b-02ec-45e4-809d-2757338240e4"
#   vehicle {
#     trip {
#       start_time: "23:39:01"
#       start_date: "20250331"
#       route_id: "9566"
#       direction_id: 0
#     }
#     position {
#       latitude: 19.4968948
#       longitude: -99.1619568
#       bearing: 271
#       odometer: 155159
#       speed: 56
#     }
#     timestamp: 1743467363
#     vehicle {
#       id: "69379"
#       label: "2306"
#       license_plate: "1240002"
#     }
#   }
# }
# entity {
#   id: "54e059c6-bf5b-48ba-a330-f20bf28084cd"
#   vehicle {
#     position {
#       latitude: 19.4648781
#       longitude: -99.0592499
#       bearing: 316
#       odometer: 147594
#       speed: 0
#     }
#     timestamp: 1743448515
#     vehicle {
#       id: "69378"
#       label: "2305"
#       license_plate: "1240001"
#     }
#   }
# }
# entity {
# ...

# %%
import pandas as pd
data = []
for entity in feed.entity:
    ## print(f"ID de entidad: {entity.id}")
    if entity.HasField('vehicle'):
        id_id = entity.id
        vehicle = entity.vehicle
        row = {
            'id':id_id,
            'vehicle_id': vehicle.vehicle.id,
            'vehicle_label': vehicle.vehicle.label,
            'start_time': vehicle.trip.start_time,
            'start_date': vehicle.trip.start_date,
            'route_id': vehicle.trip.route_id,
            'direction_id': vehicle.trip.direction_id,
            'latitude': vehicle.position.latitude,
            'longitude': vehicle.position.longitude,
            'bearing': vehicle.position.bearing,
            'odometer': vehicle.position.odometer,
            'speed': vehicle.position.speed,
            'timestamp': vehicle.timestamp
        }
        data.append(row)

dfjson = pd.DataFrame(data)

# %%
valores_duplicados=dfjson['route_id'].duplicated().sum()

# %%
valores_duplicados
# Out:
# np.int64(774)

# %%
dfjson.head(50)
# Out:
#                                       id vehicle_id vehicle_label start_time  \
# 0   2b0af44b-02ec-45e4-809d-2757338240e4      69379          2306   23:39:01
# 1   54e059c6-bf5b-48ba-a330-f20bf28084cd      69378          2305
# 2   8000a038-7f7b-4f43-9347-868f7bd99cd0      69377          2304   00:23:49
# 3   f16ff4ae-f267-4a40-a481-978ed22af2f9      69376          2303   00:23:12
# 4   017d7162-c3ea-4b62-9003-e4b9d9a853a0      69375          2302   00:29:00
# 5   ef818eab-0a29-4ef3-94fc-9a7ec9634513      69382          2309   00:13:26
# 6   e371523e-e8f4-4195-9599-992f0fbc6de4      69381          2308   23:52:15
# 7   71def0c3-2673-495b-93f3-1e5d87c7bd8b      69380          2307   00:01:27
# 8   b2d98910-d50d-45f6-8867-575364322188      69393          2320   00:20:45
# 9   4d9c1ffb-ccaa-4fb5-8a28-728d8c18c47a      69390          2317   00:28:44
# 10  124efc3f-e101-4dad-b068-57ca9ad7c981      69389          2316   00:16:53
# ...

# %%
dfjson1=dfjson.copy()

# %%
dfjson1
# Out:
#     vehicle_id vehicle_label license_plate start_time start_date route_id  \
# 0        70041           907       1280169
# 1        70042           908       1280170
# 2        70043           909       1280171
# 3        69379          2306       1240002
# 4        69378          2305       1240001
# ..         ...           ...           ...        ...        ...      ...
# 659      70037           903       1280165
# 660      70038           904       1280166
# 661      70039           905       1280167
# 662      70040           906       1280168
# 663      69671          2659       002A961
#
#      direction_id   latitude  longitude  bearing  odometer  speed   timestamp
# 0               0  19.487364 -99.092812    113.0  109865.0    0.0  1743403475
# 1               0  19.487461 -99.092857      0.0   98013.0    0.0  1743401659
# 2               0  19.487467 -99.092842      0.0   77593.0    0.0  1743401485
# ...

# %%
# # Procesar datos
for entity in feed.entity:
    if entity.HasField('vehicle'):
        if entity.vehicle.vehicle.label == "2387":
            print(entity)
            print(f"Vehículo {entity.vehicle.vehicle.id}")
            print(f"Posición: {entity.vehicle.position.latitude}, {entity.vehicle.position.longitude}")
            print(f"inicio: {entity.vehicle.trip.start_time}, {entity.vehicle.trip.start_date}")
# Out:
# id: "2b3c0815-596b-43c8-857a-21b82edc653d"
# vehicle {
#   trip {
#     start_time: "03:54:26"
#     start_date: "20250331"
#     route_id: "9612"
#     direction_id: 0
#   }
#   position {
#     latitude: 19.3881931
#     longitude: -99.0599518
#     bearing: 104
#     odometer: 103018
#     speed: 0
#   }
#   timestamp: 1743394728
#   vehicle {
#     id: "69609"
#     label: "2387"
#     license_plate: "003A020"
#   }
# }
#
# Vehículo 69609
# Posición: 19.388193130493164, -99.05995178222656
# inicio: 03:54:26, 20250331

# %%
# Out:
# Contenido de agency.txt:
# agency_id,agency_name,agency_url,agency_timezone,agency_lang,agency_phone,agency_fare_url,agency_email
# 1339,Metrobus,https://www.metrobus.cdmx.gob.mx/,America/Mexico_City,es,,https://www.metrobus.cdmx.gob.mx/,
#
# --------------------
# Contenido de calendar.txt:
# service_id,monday,tuesday,wednesday,thursday,friday,saturday,sunday,start_date,end_date
# fc73eb8fc73e9,1,1,1,1,1,1,1,20250101,20251231
# fc73eb8fc73ea,1,1,1,1,1,1,1,20250101,20251231
# 3486182348616,1,1,1,1,1,1,1,20250101,20251231
# 3486182348617,1,1,1,1,1,1,1,20250101,20251231
# 602df47602df2,1,1,1,1,1,1,0,20250101,20251231
# 602df47602df3,1,1,1,1,1,1,0,20250101,20251231
# 91fe67291fe65,1,1,1,1,1,1,1,20250101,20251231
# 91fe67291fe66,1,1,1,1,1,1,1,20250101,20251231
# 1c56a531c56a3,1,1,1,1,1,1,1,20250101,20251231
# 1c56a531c56a4,1,1,1,1,1,1,1,20250101,20251231
# 8fceb338fceb1,1,1,1,1,1,1,1,20250101,20251231
# 8fceb338fceb2,1,1,1,1,1,1,1,20250101,20251231
# ...

# %%
    with open('archivos/routes.txt', 'r', encoding='utf-8') as archivo:
        contenido = archivo.read()
        print(contenido)
# Out:
# route_id,agency_id,route_short_name,route_long_name,route_desc,route_type,route_url,route_color,route_text_color,route_sort_order,continuous_pickup,continuous_drop_off
# 19429,1339,3,L03d03-1 tenayuca - la raza,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19430,1339,3,L03d03-2 la raza - tenayuca,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19455,1339,3,L03d02-1 tenayuca - buenavista,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19456,1339,3,L03d02-2 buenavista - tenayuca,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19457,1339,3,L03d04-1 tenayuca - balderas,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19458,1339,3,L03d04-2 balderas - tenayuca,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# ...

# %%
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for gtfs-realtime-bindings: filename=gtfs_realtime_bindings-1.0.0-py3-none-any.whl size=6038 sha256=b197db65def754bdfed13a5b6fc5127f09d112bf5b3103d3f4f3b5a082615a6f
#   Stored in directory: c:\users\misael\appdata\local\pip\cache\wheels\7c\c1\b0\b839d88a76f54c82086b98ebcb3ad52cdd3e0c33a3f32d28a8
# Successfully built gtfs-realtime-bindings
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

m = folium.Map(location=[19.4326, -99.1332], zoom_start=12)
for entity in feed.entity:
    if entity.HasField('vehicle'):
        folium.Marker(
            [entity.vehicle.position.latitude, entity.vehicle.position.longitude],
            popup=f"Vehículo {entity.vehicle.vehicle.id}"
        ).add_to(m)
m.save('mapa.html')

# %%
# Out:
# ...
#
# ...

# %%
# Out:
# route_id,agency_id,route_short_name,route_long_name,route_desc,route_type,route_url,route_color,route_text_color,route_sort_order,continuous_pickup,continuous_drop_off
# 19429,1339,3,L03d03-1 tenayuca - la raza,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19430,1339,3,L03d03-2 la raza - tenayuca,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19455,1339,3,L03d02-1 tenayuca - buenavista,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19456,1339,3,L03d02-2 buenavista - tenayuca,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19457,1339,3,L03d04-1 tenayuca - balderas,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# 19458,1339,3,L03d04-2 balderas - tenayuca,,3,https://www.metrobus.cdmx.gob.mx/mapas-de-sistema/mapa-linea-3,7A9A01,FFFFFF,,,
# ...

# %%
# Out:
#     route_id  agency_id  route_short_name  \
# 0      19429       1339                 3
# 1      19430       1339                 3
# 2      19455       1339                 3
# 3      19456       1339                 3
# 4      19457       1339                 3
# ..       ...        ...               ...
# 71     20296       1339                 1
# 72     20406       1339                 1
# 73     20407       1339                 1
# 74     20439       1339                 2
# 75     20440       1339                 2
#
#                                       route_long_name  route_desc  route_type  \
# 0                         L03d03-1 tenayuca - la raza         NaN           3
# 1                         L03d03-2 la raza - tenayuca         NaN           3
# 2                      L03d02-1 tenayuca - buenavista         NaN           3
# 3                      L03d02-2 buenavista - tenayuca         NaN           3
# ...

# %%
df.head()
# Out:
#    route_id  agency_id  route_short_name                 route_long_name  \
# 0     19429       1339                 3     L03d03-1 tenayuca - la raza
# 1     19430       1339                 3     L03d03-2 la raza - tenayuca
# 2     19455       1339                 3  L03d02-1 tenayuca - buenavista
# 3     19456       1339                 3  L03d02-2 buenavista - tenayuca
# 4     19457       1339                 3    L03d04-1 tenayuca - balderas
#
#    route_desc  route_type                                          route_url  \
# 0         NaN           3  https://www.metrobus.cdmx.gob.mx/mapas-de-sist...
# 1         NaN           3  https://www.metrobus.cdmx.gob.mx/mapas-de-sist...
# 2         NaN           3  https://www.metrobus.cdmx.gob.mx/mapas-de-sist...
# 3         NaN           3  https://www.metrobus.cdmx.gob.mx/mapas-de-sist...
# 4         NaN           3  https://www.metrobus.cdmx.gob.mx/mapas-de-sist...
#
# ...

# %%
import requests
email = "misael.cardenas.reyes@gmail.com"
response = requests.get(f"https://metrobus-gtfs.sinopticoplus.com/gtfs-api/validateEmailMetrobus/{email}")
download_url = response.json().get("downloadUrl")  # Si la respuesta incluye el enlace

# %%
download_url

# %%
if download_url:
    with open("gtfs_download_link.txt", "w") as file:
        file.write(download_url)
    print(f"Enlace guardado en 'gtfs_download_link.txt': {download_url}")
else:
    print("La API no devolvió un enlace de descarga. Revisa la respuesta:")
    print(response.json())  # Para depurar
# Out:
# La API no devolvió un enlace de descarga. Revisa la respuesta:
# {'idCliente': 1339, 'nomeCliente': 'Metrobus', 'token': 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJTb25kYSIsImVtYWlsIjoibWlzYWVsLmNhcmRlbmFzLnJleWVzQGdtYWlsLmNvbSIsImlkQ2xpZW50ZSI6MTMzOSwibm9tZUNsaWVudGUiOiJNZXRyb2J1cyIsImV4cCI6MTc0MzU2MjUzNn0.hGHzzMNR_xAc2a3DUBMlekxgaDp3mtVJaAoTlfqhBO0'}

# %%
print(response.json())  # Verifica si usa otro nombre (ej: "url", "file_url")
# Out:
# {'idCliente': 1339, 'nomeCliente': 'Metrobus', 'token': 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJTb25kYSIsImVtYWlsIjoibWlzYWVsLmNhcmRlbmFzLnJleWVzQGdtYWlsLmNvbSIsImlkQ2xpZW50ZSI6MTMzOSwibm9tZUNsaWVudGUiOiJNZXRyb2J1cyIsImV4cCI6MTc0MzU2MjUzNn0.hGHzzMNR_xAc2a3DUBMlekxgaDp3mtVJaAoTlfqhBO0'}

# %%
if download_url:
    gtfs_data = requests.get(download_url)
    with open("metrobus_gtfs.zip", "wb") as file:
        file.write(gtfs_data.content)
    print("¡GTFS descargado como 'metrobus_gtfs.zip'!")

# %%
# Out:
# Error: No se encontró 'downloadUrl' en la respuesta. Revisa:
# {'idCliente': 1339, 'nomeCliente': 'Metrobus', 'token': 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJTb25kYSIsImVtYWlsIjoibWlzYWVsLmNhcmRlbmFzLnJleWVzQGdtYWlsLmNvbSIsImlkQ2xpZW50ZSI6MTMzOSwibm9tZUNsaWVudGUiOiJNZXRyb2J1cyIsImV4cCI6MTc0MzU2MjczOH0.3H4OeHf3fEt_9fb8_KoksMCuuqxvakHvCTJr2IhdhVc'}

# %%
# Out:
# Token obtenido: eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJTb25kYSIsImVtYWlsIjoibWlzYWVsLmNhcmRlbmFzLnJleWVzQGdtYWlsLmNvbSIsImlkQ2xpZW50ZSI6MTMzOSwibm9tZUNsaWVudGUiOiJNZXRyb2J1cyIsImV4cCI6MTc0MzU2MjgzMH0.WH7AYV_hNTbSAHilYa7srAAzBy-DyOmWeBzVOwKM71w
# Error al descargar. Código de estado: 404
# Respuesta del servidor: {"timestamp":"2025-04-01T03:00:31.093+00:00","status":404,"error":"Not Found","path":"/downloadGTFS"}
